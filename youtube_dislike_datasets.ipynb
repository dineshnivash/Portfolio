# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
you_tube=pd.read_csv('youtube_dislike_dataset.csv')

# %%
you_tube
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4           #NAME?                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title      published_at  \
# ...

# %%
# 1) Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.
top_5=you_tube.head()
top_5
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4       #NAME?                Why Retaining Walls Collapse
#
#                  channel_id          channel_title      published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  01-07-2021 10:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  10-06-2021 16:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  20-09-2021 01:03
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  03-03-2021 10:00
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  07-12-2021 13:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
bottom_5=you_tube.tail()
bottom_5
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title      published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  12-02-2021 05:03
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  16-01-2021 05:39
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  02-06-2021 09:00
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  20-10-2020 20:59
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  23-05-2021 21:00
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %%
# 2) check the info of the dataframe and write your inferences on data types and shape of the dataset.
you_tube.info()
#The dataset has 37422 rows and 12 columns
#The dataset contains 4 integer columns(view_count,likes,dislikes,commeny_count) and 8 object colums(video_id,title,channel_id,channel_title,published_at,tags,description and comments)
#There is no missing values(null values) in this dataset
#The memory usage of this dataframe is 3.4+ MB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
you_tube.shape
# Out:
# (37422, 12)

# %%
# 3) Check for the Percentage of the missing values and drop or impute them.
you_tube.isnull().sum() #this shows the null values of the dataset and their counts
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
you_tube.isnull().sum()/you_tube.shape[0] #this shows the percentage of missing(null) values
#this shows missing values for each column
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.004222
# dtype: float64

# %%
len(you_tube[you_tube.isnull().sum(axis=1)>0])/len(you_tube) #this will show the one value which is total number of columns missing values
# Out:
# 0.004222115333226444

# %%
you_tube.dropna(inplace=True) #To drop or remove the missing values in a dataset
you_tube
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4           #NAME?                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title      published_at  \
# ...

# %%
you_tube.isnull().sum()
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %%
# 4) Check the statistical summary of both numerical and categorical columns and write your inferences.
you_tube.describe(include='int') #this shows the statistical summary of integer values(numerical)
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.726400e+04  3.726400e+04  3.726400e+04   3.726400e+04
# mean   5.710821e+06  1.672867e+05  4.996434e+03   9.966953e+03
# std    2.431304e+07  5.384931e+05  3.075194e+04   1.173465e+05
# min    2.036800e+04  2.200000e+01  3.000000e+00   1.000000e+00
# 25%    5.141305e+05  1.331725e+04  2.827500e+02   9.140000e+02
# 50%    1.321860e+06  4.255600e+04  7.980000e+02   2.347000e+03
# 75%    3.674527e+06  1.309665e+05  2.466250e+03   6.212000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
you_tube.describe(include=['object']) #this shows the statistical summary of object values(categorical)
# Out:
#        video_id  title                channel_id        channel_title  \
# count     37264  37264                     37264                37264
# unique    36809  36956                     10891                10810
# top      #NAME?    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq        456     21                       533                  533
#
#             published_at   tags description comments
# count              37264  37264       37264    37264
# unique             29897  28694       35479    37263
# top     18-09-2020 04:00                      #NAME?
# freq                  18   3808         587        2

# %%
# 5) Convert datatype of column published_at from object to pandas datetime.
import datetime as dt #importing datetime funtion to change the object into datetime format
you_tube['published_at']=you_tube['published_at'].apply(lambda x: dt.datetime.strptime(x,'%d-%m-%Y %M:%S'))

# %%
you_tube
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4           #NAME?                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
you_tube.info() #now my data published_at column has converted from object to datetime format
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37264 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37264 non-null  object
#  1   title          37264 non-null  object
#  2   channel_id     37264 non-null  object
#  3   channel_title  37264 non-null  object
#  4   published_at   37264 non-null  datetime64[ns]
#  5   view_count     37264 non-null  int64
#  6   likes          37264 non-null  int64
#  7   dislikes       37264 non-null  int64
#  8   comment_count  37264 non-null  int64
#  9   tags           37264 non-null  object
#  10  description    37264 non-null  object
#  11  comments       37264 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 3.7+ MB

# %%
# 6) Create a new column as 'published_month' using the column published_at (display the months only)
you_tube['published_month']=you_tube['published_at'].dt.month #using dt.month to seperate a month in the published_at column

# %%
you_tube[['published_month']]
# Out:
#        published_month
# 0                    7
# 1                    6
# 2                    9
# 3                    3
# 4                   12
# ...                ...
# 37417                2
# 37418                1
# 37419                6
# 37420               10
# 37421                5
#
# [37264 rows x 1 columns]

# %%
you_tube
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4           #NAME?                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
# 7) Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.....
month_name={1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}
you_tube['published_month']=you_tube['published_month'].replace(month_name) #using dictionary and assigning 1 as jan, 2 as feb..., then replacing that as jan,feb...

# %%
you_tube
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4           #NAME?                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
# 8) Find the number of videos published each month and arrange the months in a decreasing order based on the video count.
import datetime as dt
you_tube.groupby(by='published_month')['video_id'].count().sort_values(ascending=False) #using groupby method found the count of videos published at each month
# Out:
# published_month
# Oct    4976
# Sep    4854
# Nov    4821
# Aug    4250
# Dec    3063
# Jul    2331
# Jun    2305
# Mar    2248
# Feb    2125
# Apr    2119
# Jan    2099
# May    2073
# Name: video_id, dtype: int64

# %%
# 9) Find the count of unique video_id, channel_id and channel_title.
you_tube['video_id'].unique() #unique() used to find the unique values in video_id
# Out:
# array(['--0bCF-iK2E', '--14w5SOEUs', '--40TEbZ9Is', ..., 'zzk09ESX7e0',
#        'zzmQEb0Em5I', 'zzxPZwaA-8w'], dtype=object)

# %%
you_tube['video_id'].nunique() #nunique() used to find the count of unique values in video_id
# Out:
# 36809

# %%
you_tube['channel_id'].unique()
# Out:
# array(['UC6UL29enLNe4mqwTfAyeNuw', 'UCGIelM2Dj3zza3xyV3pL3WQ',
#        'UClBKH8yZRcM4AsRjDVEdjMg', ..., 'UC95x-m2toVa_BRmmQ6SrIYg',
#        'UCb5jIJ27Ds32YE6xX3eIO3g', 'UC8NjnNWMsRqq11NYvHAQb1g'],
#       dtype=object)

# %%
you_tube['channel_id'].nunique()
# Out:
# 10891

# %%
you_tube['channel_title'].unique()
# Out:
# array(['Bundesliga', 'MigosVEVO', 'Television Academy', ...,
#        'Magnolia Network', 'Collaboration Nation', 'Master Podcast'],
#       dtype=object)

# %%
you_tube['channel_title'].nunique()
# Out:
# 10810

# %%
# 10) Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.
channel_counts = you_tube.groupby('channel_title')['video_id'].count()
channel_counts
# Out:
# channel_title
#    SilverName            1
#    [KIMDUMB]             1
#   (Inter TV channel)     1
#   -    IT!               1
#   - MBN                  1
#                         ..
# zanny                    5
# zayn                     1
# zefrank1                 9
# zollotech               10
# zoom                     1
# Name: video_id, Length: 10810, dtype: int64

# %%
top_channels = channel_counts.nlargest(10)  #top 10 channel names with highest number of videos
top_channels
# Out:
# channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: video_id, dtype: int64

# %%
bottom_channels = channel_counts.nsmallest(10) #bottom 10 channel names with lowest number of videos
bottom_channels
# Out:
# channel_title
#    SilverName            1
#    [KIMDUMB]             1
#   (Inter TV channel)     1
#   -    IT!               1
#   - MBN                  1
#   - Paris SBS-Germain    1
#   - SONGCHELIN GUIDE     1
#   - We are Family        1
#   / Fuwa Minato          1
#   / Genzuki Tojiro       1
# Name: video_id, dtype: int64

# %%
# 11) Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.
you_tube.groupby(by='title')['likes'].max().sort_values(ascending=False).head(1)
#by using groupby method found that BTS() 'Dynamite' Official MV  videos has the maximum number of likes (31837675)
#in this using a groupby method we are grouping the title and getting the likes of max number using max(), then sort the values using sort_values of selected group in descending order and getting top one title by head(1)
# Out:
# title
# BTS () 'Dynamite' Official MV    31837675
# Name: likes, dtype: int64

# %%
you_tube.groupby(by='title')['likes'].min().sort_values(ascending=False).tail(1)
#by using groupby method found that Leading the Charge | Circle K  videos has the minimum number of likes (22)
#in this using a groupby method we are grouping the title and getting the likes of min number using min(), then sort the values using sort_values of selected group in descending order and getting lowest one title by tail(1)
# Out:
# title
# Leading the Charge | Circle K    22
# Name: likes, dtype: int64

# %%
# 12) Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.
you_tube.groupby(by='title')['dislikes'].max().sort_values(ascending=False).head(1)
#by using groupby method found that Cuties | Official Trailer | Netflix videos has the maximum number of dislikes (2397733)
#in this using a groupby method we are grouping the title and getting the dislikes of max number using max(), then sort the values using sort_values of selected group in descending order and getting top one title by head(1)
# Out:
# title
# Cuties | Official Trailer | Netflix    2397733
# Name: dislikes, dtype: int64

# %%
you_tube.groupby(by='title')['dislikes'].min().sort_values(ascending=False).tail(1)
#by using groupby method found that Tims For Good: A Taste Of The Familiar videos has the minimum number of dislikes (3)
#in this using a groupby method we are grouping the title and getting the dislikes of min number using min(), then sort the values using sort_values of selected group in descending order and getting lowest one title by tail(1)
# Out:
# title
# Tims For Good: A Taste Of The Familiar    3
# Name: dislikes, dtype: int64

# %%
# 13) Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.
you_tube['view_count'].corr(you_tube['dislikes'])
# Out:
# 0.6845758297072598

# %%
import seaborn as sns
you_tube.groupby(by='view_count')['dislikes'].count().sum()
# Out:
# 37264

# %%
you_tube[['view_count','dislikes']].plot(x='view_count',y="dislikes",kind='scatter',figsize=(7,5))
plt.show()

# %%
# 14) Display all the information about the videos that were published in January, and mention the count of videos that were published in January.
jan_videos=you_tube[you_tube['published_at'].dt.month==1]

# %%
jan_videos
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95          #NAME?  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103         #NAME?              Do Ugly Foods Taste Worse? Taste Test
# 182         #NAME?                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
jan_videos[you_tube['published_at'].dt.month==1].count()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10896\2022830816.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   jan_videos[you_tube['published_at'].dt.month==1].count()
# video_id           2099
# title              2099
# channel_id         2099
# channel_title      2099
# published_at       2099
# view_count         2099
# likes              2099
# dislikes           2099
# comment_count      2099
# tags               2099
# description        2099
# comments           2099
# published_month    2099
# dtype: int64

# %%
jan_videos[you_tube['published_at'].dt.month==1].count().sum()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10896\2462880866.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   jan_videos[you_tube['published_at'].dt.month==1].count().sum()
# 27287

# %%
jan_videos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2099 entries, 27 to 37418
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   video_id         2099 non-null   object
#  1   title            2099 non-null   object
#  2   channel_id       2099 non-null   object
#  3   channel_title    2099 non-null   object
#  4   published_at     2099 non-null   datetime64[ns]
#  5   view_count       2099 non-null   int64
#  6   likes            2099 non-null   int64
#  7   dislikes         2099 non-null   int64
#  8   comment_count    2099 non-null   int64
#  9   tags             2099 non-null   object
#  10  description      2099 non-null   object
#  11  comments         2099 non-null   object
#  12  published_month  2099 non-null   object
# dtypes: datetime64[ns](1), int64(4), object(8)
# memory usage: 229.6+ KB

# %%
you_tube
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4           #NAME?                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...
